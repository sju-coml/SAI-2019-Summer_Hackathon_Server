# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from pandas import Series
import datetime as dt

df_original = pd.read_csv('dataset.csv')
df_original = df_original.sample(frac=0.1)
df_original = df_original.sort_index()

# %%
df_original
# Out:
#         Unnamed: 0        date  hour  minute  month  day      week  Friday  \
# 7                7  2018-04-01     9      59      4    1    Sunday       0
# 11              11  2018-04-01     9      59      4    1    Sunday       0
# 14              14  2018-04-01    10       0      4    1    Sunday       0
# 31              31  2018-04-01    10       5      4    1    Sunday       0
# 32              32  2018-04-01    10       5      4    1    Sunday       0
# 35              35  2018-04-01    10      11      4    1    Sunday       0
# 46              46  2018-04-01    10      20      4    1    Sunday       0
# 55              55  2018-04-01    10      22      4    1    Sunday       0
# 58              58  2018-04-01    10      22      4    1    Sunday       0
# 60              60  2018-04-01    10      29      4    1    Sunday       0
# 61              61  2018-04-01    10      29      4    1    Sunday       0
# ...

# %%
data = { "month": [4],"hour" : [0],  "Friday": [0], "Monday": [1], "Saturday": [0], "Tursday": [0], "Tuesday": [0], "Wednesday": [0], "test_season": [0], "vacation": [0], "special_day": [0], "count": [0]}

# %%
week_df = pd.DataFrame(data)

# %%
week_df
# Out:
#    month  hour  Friday  Monday  Saturday  Tursday  Tuesday  Wednesday  \
# 0      4     0       0       1         0        0        0          0
#
#    test_season  vacation  special_day  count
# 0            0         0            0      0

# %%
df_original[df_original["week"] == 'Monday']
# Out:
#        Unnamed: 0        date  month  day  hour  minute    week  Friday  \
# 92            944  2018-04-02      4    2     0       0  Monday       0
# 99            992  2018-04-02      4    2     0       0  Monday       0
# 112          1129  2018-04-02      4    2     0       0  Monday       0
# 114          1141  2018-04-02      4    2     0       0  Monday       0
# 124          1186  2018-04-02      4    2     0       0  Monday       0
# 131          1219  2018-04-02      4    2     0       0  Monday       0
# 761          7464  2018-04-16      4   16     0       0  Monday       0
# 765          7523  2018-04-16      4   16     0       0  Monday       0
# 770          7578  2018-04-16      4   16     0       0  Monday       0
# 792          7861  2018-04-16      4   16     0       0  Monday       0
# 795          7874  2018-04-16      4   16     0       0  Monday       0
# 1074        10837  2018-04-23      4   23     0       0  Monday       0
# ...

# %%
df_original["day"]
# Out:
# 7          1
# 11         1
# 14         1
# 31         1
# 32         1
# 35         1
# 46         1
# 55         1
# 58         1
# 60         1
# 61         1
# 75         1
# 104        1
# 118        1
# 120        1
# 131        1
# 164        1
# 175        1
# 180        1
# 182        1
# 196        1
# 207        1
# 220        1
# 232        1
# 239        1
# 245        1
# 253        1
# 260        1
# 263        1
# 268        1
#           ..
# 158620    28
# 158623    28
# 158632    28
# 158633    28
# 158635    28
# 158641    28
# 158642    28
# 158660    29
# 158671    29
# 158676    29
# 158691    29
# 158696    29
# 158707    29
# 158720    29
# 158730    29
# 158765    29
# 158772    29
# 158777    30
# 158791    30
# 158812    30
# 158823    30
# 158840    30
# 158846    30
# 158857    30
# 158866    30
# 158873    30
# 158883    30
# 158925    30
# 158929    30
# 158946    30
# Name: day, Length: 15895, dtype: int64

# %%
april_df = df_original[(df_original["month"] == 4)]
april_mon_df = april_df[april_df["week"] == "Monday"]

# %%
avg = 0
tmp = 0
now_m = 0
now_n = 0
c_n = 0
c_m = 0
for i in range(april_mon_df:
    tmp += 1
    if()

# %%
april_mon_df.iloc(1:2)
# Out:
#   File "<ipython-input-41-e13b35b95fb0>", line 1
#     april_mon_df.iloc(1:2)
#                        ^
# SyntaxError: invalid syntax

# %%
april_mon_df
# Out:
#         Unnamed: 0        date  hour  minute  month  day    week  Friday  \
# 865            865  2018-04-02     9      41      4    2  Monday       0
# 869            869  2018-04-02     9      42      4    2  Monday       0
# 888            888  2018-04-02    11      30      4    2  Monday       0
# 894            894  2018-04-02    11      49      4    2  Monday       0
# 896            896  2018-04-02    11      50      4    2  Monday       0
# 898            898  2018-04-02    11      50      4    2  Monday       0
# 919            919  2018-04-02    12      17      4    2  Monday       0
# 921            921  2018-04-02    12      17      4    2  Monday       0
# 931            931  2018-04-02    12      36      4    2  Monday       0
# 942            942  2018-04-02    12      48      4    2  Monday       0
# 951            951  2018-04-02    12      56      4    2  Monday       0
# 953            953  2018-04-02    12      56      4    2  Monday       0
# ...

# %%
tmp_df = df_original[(df_original["day"] == 2)]

# %%
group = df_original.groupby(["month","day", "week"]).count()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-9d0b04395cbc> in <module>
# ----> 1 group["month"]
#
# ...

# %%
mean_df = group(["month", "week"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-be19d877ab42> in <module>
# ----> 1 mean_df = group(["month", "week"]).mean()
#
# TypeError: 'DataFrame' object is not callable
